# %%
def hello():
   print("hello")
hello()
# Out:
# hello

# %%
def factorial():
   fact=1
   a=int(input("enter a number"))
   for i in range(1,a+1): fact=fact*i
   print(fact)
factorial()
# Out:
# enter a number5
# 120

# %%
def add(a,b):
   c=a+b
   print(c)
add(2,5)
# Out:
# 7

# %%
def fact(a): 
   fact=1
   for i in range(1,a+1): fact=fact*i
   print(fact)
fact(7)
# Out:
# 5040

# %%
def sum(a,b,c):
  sum=a+b+c
  avg=sum/3
  print(sum)
  print(avg)
sum(1,2,3)
# Out:
# 6
# 2.0

# %%
def mul(a,b):
  d=a*b
  print(d)
mul(2,3)
# Out:
# 6

# %%
def sub(a,b,c):
  d=a-b-c
  print(d)
sub(6,7,4)
# Out:
# -5

# %%
def sum():
  a=int(input("enter a value"))
  b=int(input("enter a value"))
  c=a+b
  return c
x=sum()
print(x)
# Out:
# enter a value5
# enter a value4
# 9
