# %%
x=[]
print(type(x))
# Out:
# <class 'list'>

# %%
x=[1,2,3,"hello"]
x
# Out:
# [1, 2, 3, 'hello']

# %% [markdown]
# TO DISPLAY EACH ELEMENT

# %%
x[0]
# Out:
# 1

# %%
x[1]
# Out:
# 2

# %%
x[2]
# Out:
# 3

# %%
x[3]
# Out:
# 'hello'

# %% [markdown]
# ELEMENTS BEFORE 3

# %%
x[:3]
# Out:
# [1, 2, 3]

# %% [markdown]
# ELEMENTS AFTER 2

# %%
x[2:]
# Out:
# [3, 'hello']

# %%
x[3:]
# Out:
# ['hello']

# %% [markdown]
# ELEMENTS AFTER 1 BEFORE 4

# %%
x[1:4]
# Out:
# [2, 3, 'hello']

# %%
x=["orange","car","bike","book","pen","phone"]
x[-1]
# Out:
# 'phone'

# %%
x[-2]
# Out:
# 'pen'

# %%
x[-4]
# Out:
# 'bike'

# %%
x[-5]
# Out:
# 'car'

# %%
x[1]="bus"

# %%
x
# Out:
# ['orange', 'bus', 'bike', 'book', 'pen', 'phone']

# %% [markdown]
# ADDING DATA (LAST POSITION)

# %%
x.append("tree")

# %%
x
# Out:
# ['orange', 'bus', 'bike', 'book', 'pen', 'phone', 'tree', 'tree']

# %% [markdown]
# PARTICULAR POSTION AND DATA ADDING

# %%
x.insert(2,"red")

# %%
x
# Out:
# ['orange', 'bus', 'red', 'bike', 'book', 'pen', 'phone', 'tree', 'tree']

# %% [markdown]
# ADDING DATA TO LAST POSITION

# %%
x.extend(["hey"])

# %%
x
# Out:
# ['orange', 'bus', 'red', 'bike', 'book', 'pen', 'phone', 'tree', 'tree', 'hey']

# %% [markdown]
# DELETE LAST DATA

# %%
x.pop()
x
# Out:
# ['orange', 'bus', 'red', 'bike', 'book', 'pen', 'phone', 'tree']

# %% [markdown]
# DELETE SPECIFIC DATA

# %%
x.remove("red")
x
# Out:
# ['orange', 'bus', 'bike', 'book', 'pen', 'phone', 'tree']

# %%
x.reverse()
x
# Out:
# ['tree', 'phone', 'pen', 'book', 'bike', 'bus', 'orange']

# %%
x.sort()
x
# Out:
# ['bike', 'book', 'bus', 'orange', 'pen', 'phone', 'tree']
