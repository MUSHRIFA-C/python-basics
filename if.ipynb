# %%
a=10
b=30
if a>b :
  print("a is greater")
else :
  print("b is greater")
# Out:
# b is greater

# %%
a=int(input("enter the number"))
if a>0: 
  print("number is positive")
elif a<0:
  print("number is negative")
elif a==0:
  print("number is zero")
# Out:
# enter the number67
# number is positive

# %%
a=int(input("enter first value:"))
b=int(input("enter second value:"))

print("choice=1,add")
print("choice=2,sub")
print("choice=3,mul")
print("choice=4,div") 
choice=int(input("enter your choice:"))
if choice==1:
   print(a+b)
elif choice==2:
   print(a-b)
elif choice==3:
   print(a*b)
elif choice==4:
   print(a/b)
# Out:
# enter first value:10
# enter second value:2
# choice=1,add
# choice=2,sub
# choice=3,mul
# choice=4,div
# enter your choice:1
# 12

# %%
from re import X
a=int(input("enter the amount"))
if(a<1500):
  print("pay the amount")
elif(a>1500):
   b=10/100*a
   print("your discount amount is",b)
   print("the total bill=",a-b)
# Out:
# enter the amount1650
# your discount amount is 165.0
# the total bill= 1485.0

# %%
x=int(input("enter the number"))
if x%2==0:
  print("number is even")
else:
  print("number is odd")
# Out:
# enter the number4
# number is even
