# %%
txt ={"name": "mushrifa",
      "age": 22,
      "dept": "CS",
      "addr": "chalil"}

# %%
print(txt)
# Out:
# {'name': 'mushrifa', 'age': 22, 'dept': 'CS', 'addr': 'chalil'}

# %%
print(type(txt))
# Out:
# <class 'dict'>

# %%
print(len(txt))
# Out:
# 4

# %%
txt["name"]
# Out:
# 'mushrifa'

# %%
txt["addr"]
# Out:
# 'chalil'

# %%
txt["addr"]="kk"

# %%
txt
# Out:
# {'name': 'mushrifa', 'age': 22, 'dept': 'CS', 'addr': 'kk'}

# %%
del txt["age"]

# %%
print(txt)
# Out:
# {'name': 'mushrifa', 'dept': 'CS', 'addr': 'kk'}

# %%
txt.clear()

# %%
print(txt)
# Out:
# {}

# %%
del txt

# %%
print(txt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-e05f41b44232> in <module>
# ----> 1 print(txt)
#
# NameError: name 'txt' is not defined
