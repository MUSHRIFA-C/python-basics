# %%
x={1,2,3}
print(type(x))
# Out:
# <class 'set'>

# %%
x.add(5)
print(x)
# Out:
# {1, 2, 3, 5}

# %%
x.remove(3)
x
# Out:
# {1, 2, 5}

# %%
x.update(["hi"])
x
# Out:
# {1, 2, 5, 'hi'}

# %%
2 in x
# Out:
# True

# %%
6 in x
# Out:
# False

# %%
x.pop()
x
# Out:
# {2, 5, 'hi'}
