# %%
str="mushrifa"
print(str)
# Out:
# mushrifa

# %%
x="10"
y=10

# %%
x
# Out:
# '10'

# %%
y
# Out:
# 10

# %%
print(type(x))
print(type(y))
# Out:
# <class 'str'>
# <class 'int'>

# %%
x=10
y=20
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# 30
# -10
# 200
# 0.5

# %%
a=input("enter your first value")
b=input("enter your second value")
a+b
# Out:
# enter your first value5
# enter your second value6
# '56'

# %%
print(type(a))
print(type(b))
# Out:
# <class 'str'>
# <class 'str'>

# %%
a=int(input("enter your first value"))
b=int(input("enter your second value"))
a+b
# Out:
# enter your first value10
# enter your second value4
# 14

# %%
str1="mushrifa"
print(len(str1))
# Out:
# 8

# %% [markdown]
# **1st letter capitalize**

# %%
str2="python is a simple lang"
str2.capitalize()
# Out:
# 'Python is a simple lang'

# %% [markdown]
# capitalize 1st letter of all **words**

# %%
str2="python is a simple lang"
str2.title()
# Out:
# 'Python Is A Simple Lang'

# %% [markdown]
# capitalize full sentence

# %%
str2="python is a simple lang"
str2.upper()
# Out:
# 'PYTHON IS A SIMPLE LANG'

# %%
str2
# Out:
# 'python is a simple lang'

# %% [markdown]
# all letters lower:

# %%
str3=("GOOD MORNING")
str3.lower()
# Out:
# 'good morning'

# %%
str2="welcome to python,it is a simple language"
x=str2.find("p")
print(x)
# Out:
# 11

# %%
str2="welcome to python,it is a simple language"
x=str2.find("w")
print(x)
# Out:
# 0

# %%
str2="welcome to python,it is a simple language"
x=str2.find("t",5,10)
print(x)
# Out:
# 8

# %%
str2="welcome to python,it is a simple language"
x=str2.count("python",5,30)
print(x)
# Out:
# 1

# %% [markdown]
# A-Z AND 0-9 CHARECTERS ARE VALID

# %%
str2="digit"
x=str2.isalnum()
print(x)
# Out:
# True

# %% [markdown]
# A-Z CHARECTERS ARE VALID

# %%
str2="welcome5"
x=str2.isalpha()
print(x)
# Out:
# False

# %%
str="1324"
x=str2.isdigit()
print(x)
# Out:
# False

# %%
str="  "
x=str.isspace()
print(x)
# Out:
# True

# %%
txt="eye"
x=txt.islower()
print(x)
# Out:
# True

# %%
txt="EYE"
x=txt.isupper()
print(x)
# Out:
# True

# %%
y="hello"
x=y.index("o")
print(x)
# Out:
# 4

# %%
txt=("hello")
x="welcome ".join(txt)
print(x)
# Out:
# hwelcome ewelcome lwelcome lwelcome o

# %%
txt="hello welcome"
x=txt.split()
print(x)
# Out:
# ['hello', 'welcome']

# %%
txt="hellowelcome"
x=txt.splitlines()
print(x)
# Out:
# ['hellowelcome']

# %%
txt="   banana   "
x=txt.strip()
print("the",x)
# Out:
# the banana

# %%
txt="the car"
x=txt.replace("car","bus")
print(x)
# Out:
# the bus

# %%
txt="the car"
x=txt.swapcase()
print(x)

# %%
txt="the "
